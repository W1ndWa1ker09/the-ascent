# %% [markdown]
# ### C++ Quick Reference (for Python Programmers)
#
# ---
#
# #### 1. `main` Function (Program Entry Point)
#
# ```cpp
# int main() {
#     // program starts here
#     return 0;
# }

# %% [markdown]
# #### 2. Console Output and Input
#
# ```cpp
# #include <iostream>
#
# std::cout << "Hello " << x << std::endl; // newline
# std::cout << "Hello\n";                  // faster newline
#
# int x;         // declare type-aware variable
# std::cin >> x; // integer input
#
# std::string name;
# std::cin >> name; // string input w/o spaces
#
# std::string line;
# std::getline(std::cin, line); // string input w/ spaces

# %% [markdown]
# #### 3. Variable Types
#
# ```cpp
# #include <string>
#
# int a = 10;              // integer
# double b = 3.14;         // float
# bool flag = true;        // true / false
# char c = 'x';            // single character
# std::string s = "hello"; // string
#
# int arr[5] = {1, 2, 3, 4, 5}; // 1d array (fixed size!)
# int grid[2][3] = {            // 2d array
#     {1, 2, 3},
#     {4, 5, 6}
# };

# %% [markdown]
# #### 4. Random Numbers
#
# ```cpp
# #include <random>
#
# std::random_device rd; // create random engine (only once)
# std::mt19937 gen(rd());  // Mersenne Twister engine
#
# std::uniform_real_distribution<> dist(0.0, 1.0); // == Python .random()
# double x = dist(gen);
#
# std::uniform_int_distribution<> dist(1, 6); // == Python .randint()
# int x = dist(gen);

# %% [markdown]
# #### 5. Vectors
#
# `std::vector` is:
# - A **dynamic** array
# - Automatically resizes
# - Stored contingously in memory
# - Closest to a Python list
#
# ```cpp
# #include <vector>
#
# std::vector<int> v = {1, 2, 3}; // 1d vector
#
# v.push_back(4); // append
# v.pop_back();   // remove last
#
# int x = v[0];    // no bounds checking
# int y = v.at(0); // bounds checked
#
# int n = v.size(); // length
#
# std::vector<std::vector<int>> grid = { // 2d vector
#     {1, 2, 3},
#     {4, 5, 6}
# };
# int x = grid[1][2];
#
# std::uniform_int_distribution<> dist(0, v.size() - 1); // == Python .choice()
# int choice = v[dist(gen)];

# %% [markdown]
# #### 6. Functions
#
# ```cpp
# int add(int a, int b) { // return type first
#     return a + b;
# }
#
# int result = add(3, 4); // 7

# %% [markdown]
# #### 7. Conditionals and Boolean Expressions
#
# | Operator | C++ |
# | --- | --- |
# | `and` | `&&` |
# | `or` | `` ` `` |
# | `not` | `!` |
#
# ```cpp
# if (x > 5) {
#     std::cout << "big\n";
# } else if (x == 5) {
#     std::cout << "equal\n";
# } else {
#     std::cout << "small\n";
# }
#
# if ((x > 0 && x < 10) ` x == 100) { // Boolean expression inside parenthesis
#     std::cout << "Between 1-10 noninclusive or 100\n";
# }

# %% [markdown]
# #### 8. Loops
#
# ```cpp
#
# while (x < 5) { // While-loop
#     x++;
# }
#
# for (int i = 0; i < 5; i++) { // For-loop over range
#     std::cout << i << "\n";
# }
#
# int arr[5] = {1, 2, 3, 4, 5};
# for (int x : arr) { // For-loop over array
#     std::cout << x << "\n";
# }

# %% [markdown]
# #### 9. Classes
#
# ```cpp
# class Person {
# public:
#     std::string name;
#     int age;
#
#     Person(std::string n, int a) { // constructor
#         name = n; // string attribute
#         age = a;  // int attribute
#     }
#
#     void greet() { // method
#         std::cout << "Hi, I'm " << name << "\n";
#     }
# };
#
# Person p("Alice", 25); // creating an object
# p.greet();
